# %% [markdown]
# # Installation
#
# 1. create a venv
#
# ````
# python3 -m venv .venv
#
# ````
#
# 2. install libraries :

# %%
# %pip install -q -U -r requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 3. activate it:
#
# ````
# source .venv/bin/activate
#
# ````

# %% [markdown]
# 4. test the imports:

# %%
from retinotopy import *
# Out:
# -----------------------------------------------------------------------------------------
# On date 2024-05-24, Running learning on host obiwan.local with device mps, pytorch==2.5.1
# -----------------------------------------------------------------------------------------
# Welcome on macOS-15.1.1-arm64-arm-64bit
# Random seed 1998 has been set.

# %% [markdown]
# ## Appendix: version of the libraries that were used

# %%
# %load_ext watermark
# %watermark -i -h -m -v -p numpy,torch,matplotlib  -r -g -b
# Out:
# Python implementation: CPython
# Python version       : 3.12.8
# IPython version      : 8.31.0
#
# numpy     : 2.2.1
# torch     : 2.5.1
# matplotlib: 3.10.0
#
# Compiler    : Clang 16.0.0 (clang-1600.0.26.4)
# OS          : Darwin
# Release     : 24.1.0
# Machine     : arm64
# Processor   : arm
# CPU cores   : 10
# Architecture: 64bit
#
# Hostname: obiwan.local
#
# Git hash: 4087edc000ee049d8877fc71dac187029c9aaa66
#
# Git repo: https://github.com/bicv/Retinotopy
#
# Git branch: main
